# %%
import pandas as pd
audits = pd.read_csv("data/Compustat Fundamentals Annual 01.2010.csv")
audits.head()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (26,30,948,949,950,955,970,975) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    gvkey  datadate   fyear indfmt consol popsrc datafmt  tic   cusip  \
# 0   1004  20100531  2009.0   INDL      C      D     STD  AIR  361105
# 1   1004  20110531  2010.0   INDL      C      D     STD  AIR  361105
# 2   1004  20120531  2011.0   INDL      C      D     STD  AIR  361105
# 3   1004  20130531  2012.0   INDL      C      D     STD  AIR  361105
# 4   1004  20140531  2013.0   INDL      C      D     STD  AIR  361105
#
#        conm  ... priusa     sic spcindcd  spcseccd  spcsrc  state stko  \
# 0  AAR CORP  ...    1.0  5080.0    110.0     925.0       B     IL  0.0
# 1  AAR CORP  ...    1.0  5080.0    110.0     925.0       B     IL  0.0
# 2  AAR CORP  ...    1.0  5080.0    110.0     925.0       B     IL  0.0
# ...

# %%
audits.shape
audits.info()
audits.isnull().sum()
audits.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152881 entries, 0 to 152880
# Columns: 981 entries, gvkey to ipodate
# dtypes: float64(937), int64(3), object(41)
# memory usage: 1.1+ GB
# gvkey         int64
# datadate      int64
# fyear       float64
# indfmt       object
# consol       object
#              ...
# state        object
# stko        float64
# weburl       object
# dldte       float64
# ipodate     float64
# Length: 981, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(audits.corr(), annot= True)

# fix overlap of values
sns.heatmap(audits.corr(), annot= True)
